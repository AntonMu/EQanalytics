# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1T62yz2zu0v2nd9CxO7E_WDlunb_5euJD' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1LAYfZ9qXTWiIDpotaGdmMsgSsoixs2W-" -O data.zip && rm -rf /tmp/cookies.txt
# Out:
# --2019-06-24 02:24:02--  https://docs.google.com/uc?export=download&confirm=DJb5&id=1LAYfZ9qXTWiIDpotaGdmMsgSsoixs2W-
# Resolving docs.google.com (docs.google.com)... 172.217.14.206, 2607:f8b0:4005:804::200e
# Connecting to docs.google.com (docs.google.com)|172.217.14.206|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k6h08cu8jdn314em2o7kqqulisj69a1t/1561341600000/14283306083758691044/*/1LAYfZ9qXTWiIDpotaGdmMsgSsoixs2W-?e=download [following]
# ...
# --2019-06-24 02:24:11--  https://doc-00-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k6h08cu8jdn314em2o7kqqulisj69a1t/1561341600000/14283306083758691044/*/1LAYfZ9qXTWiIDpotaGdmMsgSsoixs2W-?e=download
# Resolving doc-00-9o-docs.googleusercontent.com (doc-00-9o-docs.googleusercontent.com)... 216.58.195.65, 2607:f8b0:400a:808::2001
# ...

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1T62yz2zu0v2nd9CxO7E_WDlunb_5euJD' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1VqHrgH5x11lyopCKrSMIdQK70ASEdYG4" -O data.zip && rm -rf /tmp/cookies.txt
# Out:
# --2019-06-24 05:17:44--  https://docs.google.com/uc?export=download&confirm=P1JP&id=1VqHrgH5x11lyopCKrSMIdQK70ASEdYG4
# Resolving docs.google.com (docs.google.com)... 216.58.194.206, 2607:f8b0:4005:808::200e
# Connecting to docs.google.com (docs.google.com)|216.58.194.206|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-a0-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/4r6omeve0a7qmb0jv181tunm8366q47n/1561348800000/13991025076890319136/*/1VqHrgH5x11lyopCKrSMIdQK70ASEdYG4?e=download [following]
# ...
# --2019-06-24 05:17:46--  https://doc-04-a0-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/4r6omeve0a7qmb0jv181tunm8366q47n/1561348800000/13991025076890319136/*/1VqHrgH5x11lyopCKrSMIdQK70ASEdYG4?e=download
# Resolving doc-04-a0-docs.googleusercontent.com (doc-04-a0-docs.googleusercontent.com)... 172.217.14.193, 2607:f8b0:400a:803::2001
# ...

# %%
# !unzip '../data/data.zip' -d '../data/LogosInTheWild-v2/data_cleaned/voc_format'
# Out:
# Archive:  ../data/data.zip
#   inflating: ../data/LogosInTheWild-v2/data_cleaned/voc_format/view_vulnerable_1560451308_+37.810209_-122.259420_10_240+GRAND+AV+OAKLAND+Done---Level-1.jpg
#   inflating: ../data/LogosInTheWild-v2/data_cleaned/voc_format/view_vulnerable_1560451308_+37.810209_-122.259420_10_240+GRAND+AV+OAKLAND+Done---Level-1.xml
#   inflating: ../data/LogosInTheWild-v2/data_cleaned/voc_format/view_vulnerable_1560451309_+37.806846_-122.272914_10_1605+CLAY+ST+OAKLAND+Done---Level-1.jpg
#   inflating: ../data/LogosInTheWild-v2/data_cleaned/voc_format/view_vulnerable_1560451309_+37.806846_-122.272914_10_1605+CLAY+ST+OAKLAND+Done---Level-1.xml
#   inflating: ../data/LogosInTheWild-v2/data_cleaned/voc_format/view_vulnerable_1560451309_+37.850406_-122.261100_10_6408+IRWIN+CT+OAKLAND+Done---Level-1.jpg
#   inflating: ../data/LogosInTheWild-v2/data_cleaned/voc_format/view_vulnerable_1560451309_+37.850406_-122.261100_10_6408+IRWIN+CT+OAKLAND+Done---Level-1.xml
# ...
